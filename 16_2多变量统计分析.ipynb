# %%
import pandas as pd
import mytools

# %%
数据表 = mytools.读取SPSS数据文件(R'C:\Users\34426\Desktop\zqlwx\国家认同数据清理后.sav',True)
数据表.columns
# Out:
# Index(['问卷编号', '调查员', '民族', '政治面貌', '年级', '您觉得自己是个典型的中国人吗',
#        '与世界其他国家的人相比中国人有自己的特点吗', '为公民，最基本的要求是爱自己的国家', '不管是汉族还是少数民族，都是中华民族的一员',
#        '您是否为为中华民族的历史文化而骄傲', '个人的前途与命运是与中华民族的命运息息相关', '您是否了解中华民族的传统节日',
#        '您是否了解中国历史、地理、政治等', '老实说，您觉得中国怎么样', '您认为中国有多少值得自豪的地方',
#        '您认为世界有多少比例的人尊重中国', '对您而言作为一名中国人有多重要', '会以中国人自豪吗', '会隐瞒身份吗', '会打多少分',
#        '国歌升起', '世博会', '中国传统文化', '发展信心', '你会为中国运动员呐喊助威', '遇到灾难时中国人应该伸出援手',
#        '你愿意加入其他国籍吗', '中国人要为祖国统一奋斗吗'],
#       dtype='object')

# %%
# 创建年级、政治面貌和您是否了解中华民族的传统节日的交互表
cross_tab = pd.crosstab(index=[数据表['年级'], 数据表['政治面貌']], 
                        columns=数据表['您是否了解中华民族的传统节日'], 
                        margins=True, normalize=True)  # All 行和列的总和

cross_tab
# Out:
# 您是否了解中华民族的传统节日     完全不了解      不太了解      比较了解      完全了解       All
# 年级  政治面貌
# 预科  团员          0.000000  0.006418  0.007702  0.001284  0.015404
#     群众          0.000000  0.001284  0.000000  0.000000  0.001284
# 大一  团员          0.003851  0.032092  0.196406  0.059050  0.291399
#     党员          0.000000  0.000000  0.011553  0.003851  0.015404
#     群众          0.000000  0.007702  0.017972  0.007702  0.033376
#     其他          0.001284  0.001284  0.001284  0.000000  0.003851
# 大二  团员          0.001284  0.039795  0.147625  0.056483  0.245186
#     党员          0.000000  0.002567  0.017972  0.014121  0.034660
#     群众          0.000000  0.002567  0.025674  0.005135  0.033376
#     其他          0.000000  0.002567  0.003851  0.000000  0.006418
# 大三  团员          0.001284  0.017972  0.075738  0.016688  0.111682
#     党员          0.001284  0.010270  0.029525  0.015404  0.056483
#     群众          0.000000  0.003851  0.016688  0.007702  0.028241
#     其他          0.000000  0.000000  0.008986  0.001284  0.010270
# 大四  团员          0.001284  0.007702  0.046213  0.017972  0.073171
#     党员          0.001284  0.003851  0.017972  0.002567  0.025674
#     群众          0.000000  0.002567  0.007702  0.003851  0.014121
# All             0.011553  0.142490  0.632863  0.213094  1.000000

# %%
from scipy import stats
specific_grade = '大四'
# 筛选出特定年级的数据
df_specific_grade = 数据表[数据表['年级'] == specific_grade]

# %%
mytools.两个无序类别变量的统计分析(df_specific_grade,'政治面貌','您是否了解中华民族的传统节日')
# Out:
# tau_y系数: 0.0132 极弱相关或无相关
# 您是否了解中华民族的传统节日     完全不了解      不太了解      比较了解      完全了解       All
# 政治面貌
# 团员              0.011364  0.068182  0.409091  0.159091  0.647727
# 党员              0.011364  0.034091  0.159091  0.022727  0.227273
# 群众              0.000000  0.022727  0.068182  0.034091  0.125000
# All             0.022727  0.125000  0.636364  0.215909  1.000000
# 卡方值： 3.45, p值： 0.7509,自由度:6。
# 接受虚无假设

# %%
# 创建政治面貌和您是否了解中华民族的传统节日的交互表
cross_tab_specific_grade = pd.crosstab(df_specific_grade['您是否了解中华民族的传统节日'], df_specific_grade['政治面貌'])
cross_tab
# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)
chi2_grade, p_grade, dof_grade, # 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)
chi2_grade, p_grade, dof_grade,
# Out:
# (3.4477533546785626, 0.7509074124308858, 6)
