# %%
# 单变量描述统计

## 无序类别变量描述统计

import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["font.sans-serif"]=["SimHei"]# 设置字体
df=pd.read_spss(R"C:\Users\34426\Desktop\zqlwx\identity.sav")

# %%
df["民族"].value_counts(normalize=True)
# Out:
# 民族
# 汉族      0.424277
# 回族      0.152601
# 藏族      0.057803
# 蒙古族     0.057803
# 壮族      0.054335
# 土家族     0.053179
# 维吾尔族    0.053179
# 苗族      0.039306
# 彝族      0.017341
# 白族      0.017341
# 满族      0.012717
# 哈萨克族    0.011561
# 瑶族      0.009249
# 布依族     0.008092
# 侗族      0.005780
# 东乡族     0.004624
# 黎族      0.003468
# 哈尼族     0.003468
# 水族      0.002312
# 仫佬族     0.002312
# 羌族      0.002312
# 畲族      0.001156
# 土族      0.001156
# 其他      0.001156
# 保安族     0.001156
# 裕固族     0.001156
# 毛难族     0.001156
# Name: proportion, dtype: float64

# %%
x = df["民族"].value_counts().index  
y = df['民族'].value_counts(normalize=True).values * 100  
fig, ax = plt.subplots() 
# 在bar函数中增加autopct参数     
ax.bar(x, y, autopct="%.1f%%", color="blue")  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\34426\Desktop\zqlwx\description.ipynb 单元格 3 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/34426/Desktop/zqlwx/description.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> fig, ax = plt.subplots()
#       <a href='vscode-notebook-cell:/c%3A/Users/34426/Desktop/zqlwx/description.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> # 在bar函数中增加autopct参数
# ----> <a href='vscode-notebook-cell:/c%3A/Users/34426/Desktop/zqlwx/description.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> ax.bar(x, y, autopct="%.1f%%", color="blue")
#       <a href='vscode-notebook-cell:/c%3A/Users/34426/Desktop/zqlwx/description.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> plt.show()
#
# File c:\Users\34426\AppData\Local\Programs\Python\Python38\lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
# ...

# %%
x = df["民族"].value_counts().index
y = df['民族'].value_counts(normalize=True).values * 100
fig, ax2 = plt.subplots()
labels=df["民族"].value_counts().index
ax2.pie(y, autopct="%1.1f%%", labels=labels,textprops=dict(color="w"))
plt.show()
